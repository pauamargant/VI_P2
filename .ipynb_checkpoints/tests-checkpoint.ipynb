# %%
# %load_ext autoreload 
# %autoreload 2
# %reload_ext autoreload

from p1_graphs import *
import altair as alt
accident_data = get_accident_data(fname="dataset_v1.csv",sample=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
accident_data = get_accident_data("dataset_v1.csv", sample=False)

mapa = get_map()
ny_df, bur = get_buroughs(mapa)
# normalize bur and accident data BoroName
bur = bur.reset_index()
hex_data = calculate_spatial_data(accident_data, mapa)
choropleth, bar_chart = plot_map(hex_data, mapa, ny_df, bur)

choropleth | bar_chart
# Out:
# c:\Users\pamar\anaconda3\envs\VI\Lib\site-packages\IPython\core\interactiveshell.py:3526: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Index(['index_left', 'index', 'BoroCode', 'BoroName', 'Shape_Leng',
#        'Shape_Area', 'geometry'],
#       dtype='object')
# c:\Users\pamar\anaconda3\envs\VI\Lib\site-packages\altair\utils\deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# c:\Users\pamar\anaconda3\envs\VI\Lib\site-packages\altair\vegalite\v5\api.py:394: AltairDeprecationWarning: The value of 'empty' should be True or False.
#   warnings.warn(
# c:\Users\pamar\anaconda3\envs\VI\Lib\site-packages\altair\utils\deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.HConcatChart(...)

# %%
colors = {"bg": "#eff0f3", "col1": "#d8b365", "col2": "#5ab4ac"}
w=600
h=400
weather_data = get_weather_data(accident_data,fname = "weather.csv")

per_day = (
    weather_data[["date", "conditions", "CRASH TIME"]]
    .groupby(["date"])
    .count()
    .reset_index()
)


alt.Chart(per_day).mark_bar(height=3,orient="horizontal"
    ).transform_aggregate(
        mean_cond = "mean()",
        groupby=["conditions"]
    ).transform_aggregate(
        mean = "mean()",
        groupby = []
    ).transform_calculate(
        diff = "datum.mean_cond-datum.mean"
    ).encode(
        y=alt.Y("conditions:N", sort="x"),
        x=alt.X("diff:Q"),
        color=alt.condition(
            alt.datum.diff > 0,
            alt.value(colors["col2"]),  # The positive color
            alt.value(colors["col1"]),  # The negative color
        ),
    ).properties(width=w, height=h)
# Out:
# alt.Chart(...)

# %%
mean = per_day["CRASH TIME"].mean()

# mean per conditions
per_day_cond = (
    weather_data[["date", "conditions", "CRASH TIME"]]
    .groupby(["date", "conditions"])
    .count()
    .reset_index()
)
mean_cond = (
    per_day_cond[["conditions", "CRASH TIME"]]
    .groupby(["conditions"])
    .mean()
    .reset_index()
)
mean_cond.columns = ["conditions", "mean_cond"]

mean_cond["diff"] = mean_cond["mean_cond"].apply(lambda x: x - mean)
bars = (
    alt.Chart(mean_cond)
    .mark_bar(height=3, orient="horizontal")
    .encode(
        y=alt.Y("conditions:N").sort("x"),
        x="diff:Q",
        color=alt.condition(
            alt.datum.diff > 0,
            alt.value(colors["col2"]),  # The positive color
            alt.value(colors["col1"]),  # The negative color
        ),
    )
    .properties(width=w, height=h)
)
min_diff = mean_cond["diff"].min() - 0.1
max_diff = mean_cond["diff"].max() + 0.1
domain = [min_diff, max_diff]
points = (
    alt.Chart(mean_cond)
    .mark_point(orient="horizontal", size=100, opacity=1, fillOpacity=1)
    .encode(
        y=alt.Y(
            "conditions:N",
            title="Conditions",
            sort="x",
            axis=alt.Axis(titleFontSize=14),
        ),
        x=alt.X("diff:Q", scale=alt.Scale(domain=domain)).title(
            "Difference in percentage"
        ),
        color=alt.condition(
            alt.datum.diff > 0,
            alt.value(colors["col2"]),  # The positive color
            alt.value(colors["col1"]),  # The negative color
        ),
        fill=alt.condition(
            alt.datum.diff > 0,
            alt.value(colors["col2"]),  # The positive color
            alt.value(colors["col1"]),  # The negative color
        ),
    )
    .properties(width=w, height=h)
)
bars+points

# %%
weather_data = get_weather_data(accident_data,fname = "weather.csv")

chart = weather_chart(weather_data)
# Out:
# alt.LayerChart(...)

# %%
import geopandas as gpd
import geoplot as gplt

buroughs = gpd.read_file(gplt.datasets.get_path('nyc_boroughs'))
df = data.dropna(subset=["LATITUDE", "LONGITUDE"])
print(df.shape)
gdf = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.LONGITUDE, df.LATITUDE)
)
gdf = gdf.set_crs(epsg=4326, inplace=True)
print(gdf.shape)
gdf = gpd.sjoin(buroughs, gdf,  how="inner", op="intersects")
print(gdf.shape)
# Out:
# (958, 9)
# (958, 10)
# (945, 15)
# c:\Users\pamar\anaconda3\envs\VI\Lib\site-packages\IPython\core\interactiveshell.py:3466: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
